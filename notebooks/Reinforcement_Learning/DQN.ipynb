# %% [markdown]
# # Deep Q-Network (DQN) in Python
#
# This notebook demonstrates how to implement a Deep Q-Network using PyTorch and OpenAI Gym.

# %% [markdown]
# # **Step 1: Import Libraries**

# %%
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# %% [markdown]
# # **Step 2: Define DQN Model**

# %%
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_dim)
    
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# # **Step 3: Initialize Environment and Hyperparameters**

# %%
# Create CartPole environment
env = gym.make("CartPole-v1")
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

dqn = DQN(state_dim, action_dim)
optimizer = optim.Adam(dqn.parameters(), lr=0.001)
loss_fn = nn.MSELoss()

replay_buffer = deque(maxlen=10000)

# %% [markdown]
# # **Step 4: Define Training Parameters**

# %%
epsilon = 1.0  # Initial exploration rate
epsilon_decay = 0.995
min_epsilon = 0.01
discount_factor = 0.99
batch_size = 32
num_episodes = 500

# %% [markdown]
# # **Step 5: Define Training Loop**

# %%
def train_dqn():
    global epsilon  # Move this to the start
    for episode in range(num_episodes):
        state, _ = env.reset()
        state = torch.FloatTensor(state).unsqueeze(0)
        total_reward = 0
        done = False
        while not done:
            # Choose action (epsilon-greedy policy)
            if np.random.rand() < epsilon:
                action = env.action_space.sample()
            else:
                action = torch.argmax(dqn(state)).item()
            
            # Take action
            new_state, reward, done, _, _ = env.step(action)
            new_state = torch.FloatTensor(new_state).unsqueeze(0)
            replay_buffer.append((state, action, reward, new_state, done))
            state = new_state
            total_reward += reward

            # Training step
            if len(replay_buffer) > batch_size:
                minibatch = random.sample(replay_buffer, batch_size)
                states, actions, rewards, new_states, dones = zip(*minibatch)
                states = torch.cat(states)
                actions = torch.LongTensor(actions).unsqueeze(1)
                rewards = torch.FloatTensor(rewards).unsqueeze(1)
                new_states = torch.cat(new_states)
                dones = torch.FloatTensor(dones).unsqueeze(1)
                
                q_values = dqn(states).gather(1, actions)
                next_q_values = dqn(new_states).max(1, keepdim=True)[0].detach()
                target_q_values = rewards + (discount_factor * next_q_values * (1 - dones))
                
                loss = loss_fn(q_values, target_q_values)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        # Decay epsilon
        epsilon = max(min_epsilon, epsilon * epsilon_decay)
        print(f"Episode {episode+1}, Total Reward: {total_reward}")

# %% [markdown]
# # **Step 6: Train the DQN Agent**

# %%
train_dqn()
# Out:
# Episode 1, Total Reward: 14.0
# Episode 2, Total Reward: 31.0
# Episode 3, Total Reward: 53.0
# Episode 4, Total Reward: 15.0
# Episode 5, Total Reward: 17.0
# Episode 6, Total Reward: 17.0
# Episode 7, Total Reward: 15.0
# Episode 8, Total Reward: 32.0
# Episode 9, Total Reward: 17.0
# Episode 10, Total Reward: 17.0
# Episode 11, Total Reward: 22.0
# Episode 12, Total Reward: 9.0
# Episode 13, Total Reward: 13.0
# Episode 14, Total Reward: 13.0
# Episode 15, Total Reward: 28.0
# Episode 16, Total Reward: 13.0
# Episode 17, Total Reward: 27.0
# Episode 18, Total Reward: 22.0
# Episode 19, Total Reward: 22.0
# Episode 20, Total Reward: 18.0
# Episode 21, Total Reward: 21.0
# Episode 432, Total Reward: 10965.0
# Episode 433, Total Reward: 509.0
# Episode 434, Total Reward: 785.0
# Episode 435, Total Reward: 95.0
# Episode 436, Total Reward: 10.0
# Episode 437, Total Reward: 9.0
# Episode 438, Total Reward: 11.0
# Episode 439, Total Reward: 8.0
# Episode 440, Total Reward: 9.0
# Episode 441, Total Reward: 8.0
# Episode 442, Total Reward: 11.0
# Episode 443, Total Reward: 10.0
# Episode 444, Total Reward: 9.0
# Episode 445, Total Reward: 9.0
# Episode 446, Total Reward: 12.0
# Episode 447, Total Reward: 13.0
# Episode 448, Total Reward: 11.0
# Episode 449, Total Reward: 12.0
# Episode 450, Total Reward: 10.0
# Episode 451, Total Reward: 10.0
# Episode 452, Total Reward: 10.0
# Episode 453, Total Reward: 11.0
# Episode 454, Total Reward: 10.0
# Episode 455, Total Reward: 10.0
# Episode 456, Total Reward: 9.0
# Episode 457, Total Reward: 9.0
# Episode 458, Total Reward: 9.0
# Episode 459, Total Reward: 10.0
# Episode 460, Total Reward: 10.0
# Episode 461, Total Reward: 9.0
# Episode 462, Total Reward: 10.0
# Episode 463, Total Reward: 10.0
# Episode 464, Total Reward: 10.0
# Episode 465, Total Reward: 10.0
# Episode 466, Total Reward: 10.0
# Episode 467, Total Reward: 10.0
# Episode 468, Total Reward: 319.0
# Episode 469, Total Reward: 14.0
# Episode 470, Total Reward: 13.0
# Episode 471, Total Reward: 2389.0
# Episode 472, Total Reward: 11.0
# Episode 473, Total Reward: 10.0
# Episode 474, Total Reward: 10.0
# Episode 475, Total Reward: 9.0
# Episode 476, Total Reward: 9.0
# Episode 477, Total Reward: 11.0
# Episode 478, Total Reward: 9.0
# Episode 479, Total Reward: 10.0
# Episode 480, Total Reward: 8.0
# Episode 481, Total Reward: 10.0
# Episode 482, Total Reward: 10.0
# Episode 483, Total Reward: 9.0
# Episode 484, Total Reward: 10.0
# Episode 485, Total Reward: 10.0
# Episode 486, Total Reward: 9.0
# Episode 487, Total Reward: 12.0
# Episode 488, Total Reward: 10.0
# Episode 489, Total Reward: 11.0
# Episode 490, Total Reward: 10.0
# Episode 491, Total Reward: 11.0
# Episode 492, Total Reward: 8.0
# Episode 493, Total Reward: 11.0
# Episode 494, Total Reward: 9.0
# Episode 495, Total Reward: 12.0
# Episode 496, Total Reward: 9.0
# Episode 497, Total Reward: 11.0
# Episode 498, Total Reward: 11.0
# Episode 499, Total Reward: 10.0
# Episode 500, Total Reward: 9.0

# %% [markdown]
# # **Step 7: Test the Trained Agent**

# %%
def test_dqn():
    state, _ = env.reset()
    state = torch.FloatTensor(state).unsqueeze(0)
    done = False
    total_reward = 0
    while not done:
        action = torch.argmax(dqn(state)).item()
        new_state, reward, done, _, _ = env.step(action)
        state = torch.FloatTensor(new_state).unsqueeze(0)
        total_reward += reward
    print(f"Test Run Total Reward: {total_reward}")

# %%
test_dqn()
# Out:
# Test Run Total Reward: 10.0
